# %%
# %cd /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/dis2p_reproducibility/reproduce_benchmarks/kang/MIG/results
# Out:
# /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/dis2p_reproducibility/reproduce_benchmarks/kang/MIG/results

# %%
import pickle
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
# !ls
# Out:
#  Biolord_split_B_MI_results.pkl
# 'Biolord_split_CD14 Mono_MI_results.pkl'
# 'Biolord_split_CD16 Mono_MI_results.pkl'
# 'Biolord_split_CD4 T_MI_results.pkl'
# 'Biolord_split_CD8 T_MI_results.pkl'
#  Biolord_split_DC_MI_results.pkl
#  Biolord_split_NK_MI_results.pkl
#  Biolord_split_T_MI_results.pkl
#  dis2p_cE_split_B_MI_results.pkl
# 'dis2p_cE_split_CD14 Mono_MI_results.pkl'
# 'dis2p_cE_split_CD16 Mono_MI_results.pkl'
# 'dis2p_cE_split_CD4 T_MI_results.pkl'
# 'dis2p_cE_split_CD8 T_MI_results.pkl'
#  dis2p_cE_split_DC_MI_results.pkl
#  dis2p_cE_split_NK_MI_results.pkl
#  dis2p_cE_split_T_MI_results.pkl
#  scDisInfact_split_B_MI_results.pkl
# 'scDisInfact_split_CD14 Mono_MI_results.pkl'
# 'scDisInfact_split_CD16 Mono_MI_results.pkl'
# 'scDisInfact_split_CD4 T_MI_results.pkl'
# 'scDisInfact_split_CD8 T_MI_results.pkl'
#  scDisInfact_split_DC_MI_results.pkl
#  scDisInfact_split_NK_MI_results.pkl
#  scDisInfact_split_T_MI_results.pkl

# %%
mig_max = {}
mig_cat = {}
for file in os.listdir():
    with open(file, 'rb') as fp:
        MI, MI_not_max, MI_not, MI_dif_max, MI_dif, maxMIG, concatMIG = pickle.load(fp)
        mig_max[file] = maxMIG
        mig_cat[file] = concatMIG

# %%
mig_max_df = pd.DataFrame(mig_max, index=['MaxMIG']).T
mig_max_df
# Out:
#                                               MaxMIG
# Biolord_split_B_MI_results.pkl              0.620112
# scDisInfact_split_CD16 Mono_MI_results.pkl -0.424323
# scDisInfact_split_CD8 T_MI_results.pkl     -0.414937
# scDisInfact_split_NK_MI_results.pkl        -0.430180
# scDisInfact_split_T_MI_results.pkl         -0.393883
# scDisInfact_split_DC_MI_results.pkl        -0.421606
# scDisInfact_split_CD4 T_MI_results.pkl     -0.403786
# dis2p_cE_split_DC_MI_results.pkl            0.768627
# scDisInfact_split_B_MI_results.pkl         -0.375486
# dis2p_cE_split_CD16 Mono_MI_results.pkl     0.677135
# Biolord_split_CD4 T_MI_results.pkl          0.609861
# dis2p_cE_split_NK_MI_results.pkl            0.711337
# Biolord_split_CD14 Mono_MI_results.pkl      0.666108
# Biolord_split_CD8 T_MI_results.pkl          0.685887
# Biolord_split_CD16 Mono_MI_results.pkl      0.665990
# dis2p_cE_split_CD8 T_MI_results.pkl         0.705154
# dis2p_cE_split_CD4 T_MI_results.pkl         0.735023
# dis2p_cE_split_T_MI_results.pkl             0.691922
# Biolord_split_DC_MI_results.pkl             0.621977
# Biolord_split_NK_MI_results.pkl             0.643924
# Biolord_split_T_MI_results.pkl              0.638725
# dis2p_cE_split_CD14 Mono_MI_results.pkl     0.725511
# scDisInfact_split_CD14 Mono_MI_results.pkl -0.198023
# dis2p_cE_split_B_MI_results.pkl             0.724274

# %%
mig_cat_df = pd.DataFrame(mig_cat, index=['ConcatMIG']).T
mig_cat_df
# Out:
#                                             ConcatMIG
# Biolord_split_B_MI_results.pkl               0.620112
# scDisInfact_split_CD16 Mono_MI_results.pkl  -0.423035
# scDisInfact_split_CD8 T_MI_results.pkl      -0.420468
# scDisInfact_split_NK_MI_results.pkl         -0.431541
# scDisInfact_split_T_MI_results.pkl          -0.396200
# scDisInfact_split_DC_MI_results.pkl         -0.422618
# scDisInfact_split_CD4 T_MI_results.pkl      -0.397118
# dis2p_cE_split_DC_MI_results.pkl             0.752986
# scDisInfact_split_B_MI_results.pkl          -0.383955
# dis2p_cE_split_CD16 Mono_MI_results.pkl      0.696111
# Biolord_split_CD4 T_MI_results.pkl           0.609861
# dis2p_cE_split_NK_MI_results.pkl             0.734542
# Biolord_split_CD14 Mono_MI_results.pkl       0.666108
# Biolord_split_CD8 T_MI_results.pkl           0.699419
# Biolord_split_CD16 Mono_MI_results.pkl       0.665990
# dis2p_cE_split_CD8 T_MI_results.pkl          0.724621
# dis2p_cE_split_CD4 T_MI_results.pkl          0.662989
# dis2p_cE_split_T_MI_results.pkl              0.687882
# Biolord_split_DC_MI_results.pkl              0.621977
# Biolord_split_NK_MI_results.pkl              0.643924
# Biolord_split_T_MI_results.pkl               0.638725
# dis2p_cE_split_CD14 Mono_MI_results.pkl      0.692826
# scDisInfact_split_CD14 Mono_MI_results.pkl  -0.221657
# dis2p_cE_split_B_MI_results.pkl              0.736369

# %%
df1 = mig_max_df.copy()
df1['Split'] = df1.index.str.split('_').str[-3]
df1['Model'] = df1.index.str.split('_').str[0]
df1['Metric'] = 'maxMIG'
df1['Value'] = df1['MaxMIG']
df1 = df1.drop(columns=['MaxMIG'])

df2 = mig_cat_df.copy()
df2['Split'] = df2.index.str.split('_').str[-3]
df2['Model'] = df2.index.str.split('_').str[0]
df2['Metric'] = 'concatMIG'
df2['Value'] = df2['ConcatMIG']
df2 = df2.drop(columns=['ConcatMIG'])

df = pd.concat([df1, df2])
df
# Out:
#                                                 Split        Model     Metric  \
# Biolord_split_B_MI_results.pkl                      B      Biolord     maxMIG
# scDisInfact_split_CD16 Mono_MI_results.pkl  CD16 Mono  scDisInfact     maxMIG
# scDisInfact_split_CD8 T_MI_results.pkl          CD8 T  scDisInfact     maxMIG
# scDisInfact_split_NK_MI_results.pkl                NK  scDisInfact     maxMIG
# scDisInfact_split_T_MI_results.pkl                  T  scDisInfact     maxMIG
# scDisInfact_split_DC_MI_results.pkl                DC  scDisInfact     maxMIG
# scDisInfact_split_CD4 T_MI_results.pkl          CD4 T  scDisInfact     maxMIG
# dis2p_cE_split_DC_MI_results.pkl                   DC        dis2p     maxMIG
# scDisInfact_split_B_MI_results.pkl                  B  scDisInfact     maxMIG
# dis2p_cE_split_CD16 Mono_MI_results.pkl     CD16 Mono        dis2p     maxMIG
# Biolord_split_CD4 T_MI_results.pkl              CD4 T      Biolord     maxMIG
# dis2p_cE_split_NK_MI_results.pkl                   NK        dis2p     maxMIG
# Biolord_split_CD14 Mono_MI_results.pkl      CD14 Mono      Biolord     maxMIG
# Biolord_split_CD8 T_MI_results.pkl              CD8 T      Biolord     maxMIG
# Biolord_split_CD16 Mono_MI_results.pkl      CD16 Mono      Biolord     maxMIG
# dis2p_cE_split_CD8 T_MI_results.pkl             CD8 T        dis2p     maxMIG
# dis2p_cE_split_CD4 T_MI_results.pkl             CD4 T        dis2p     maxMIG
# dis2p_cE_split_T_MI_results.pkl                     T        dis2p     maxMIG
# Biolord_split_DC_MI_results.pkl                    DC      Biolord     maxMIG
# Biolord_split_NK_MI_results.pkl                    NK      Biolord     maxMIG
# Biolord_split_T_MI_results.pkl                      T      Biolord     maxMIG
# dis2p_cE_split_CD14 Mono_MI_results.pkl     CD14 Mono        dis2p     maxMIG
# scDisInfact_split_CD14 Mono_MI_results.pkl  CD14 Mono  scDisInfact     maxMIG
# dis2p_cE_split_B_MI_results.pkl                     B        dis2p     maxMIG
# Biolord_split_B_MI_results.pkl                      B      Biolord  concatMIG
# scDisInfact_split_CD16 Mono_MI_results.pkl  CD16 Mono  scDisInfact  concatMIG
# scDisInfact_split_CD8 T_MI_results.pkl          CD8 T  scDisInfact  concatMIG
# scDisInfact_split_NK_MI_results.pkl                NK  scDisInfact  concatMIG
# scDisInfact_split_T_MI_results.pkl                  T  scDisInfact  concatMIG
# scDisInfact_split_DC_MI_results.pkl                DC  scDisInfact  concatMIG
# scDisInfact_split_CD4 T_MI_results.pkl          CD4 T  scDisInfact  concatMIG
# dis2p_cE_split_DC_MI_results.pkl                   DC        dis2p  concatMIG
# scDisInfact_split_B_MI_results.pkl                  B  scDisInfact  concatMIG
# dis2p_cE_split_CD16 Mono_MI_results.pkl     CD16 Mono        dis2p  concatMIG
# Biolord_split_CD4 T_MI_results.pkl              CD4 T      Biolord  concatMIG
# dis2p_cE_split_NK_MI_results.pkl                   NK        dis2p  concatMIG
# Biolord_split_CD14 Mono_MI_results.pkl      CD14 Mono      Biolord  concatMIG
# Biolord_split_CD8 T_MI_results.pkl              CD8 T      Biolord  concatMIG
# Biolord_split_CD16 Mono_MI_results.pkl      CD16 Mono      Biolord  concatMIG
# dis2p_cE_split_CD8 T_MI_results.pkl             CD8 T        dis2p  concatMIG
# dis2p_cE_split_CD4 T_MI_results.pkl             CD4 T        dis2p  concatMIG
# dis2p_cE_split_T_MI_results.pkl                     T        dis2p  concatMIG
# Biolord_split_DC_MI_results.pkl                    DC      Biolord  concatMIG
# Biolord_split_NK_MI_results.pkl                    NK      Biolord  concatMIG
# Biolord_split_T_MI_results.pkl                      T      Biolord  concatMIG
# dis2p_cE_split_CD14 Mono_MI_results.pkl     CD14 Mono        dis2p  concatMIG
# scDisInfact_split_CD14 Mono_MI_results.pkl  CD14 Mono  scDisInfact  concatMIG
# dis2p_cE_split_B_MI_results.pkl                     B        dis2p  concatMIG
#
#                                                Value
# Biolord_split_B_MI_results.pkl              0.620112
# scDisInfact_split_CD16 Mono_MI_results.pkl -0.424323
# scDisInfact_split_CD8 T_MI_results.pkl     -0.414937
# scDisInfact_split_NK_MI_results.pkl        -0.430180
# scDisInfact_split_T_MI_results.pkl         -0.393883
# scDisInfact_split_DC_MI_results.pkl        -0.421606
# scDisInfact_split_CD4 T_MI_results.pkl     -0.403786
# dis2p_cE_split_DC_MI_results.pkl            0.768627
# scDisInfact_split_B_MI_results.pkl         -0.375486
# dis2p_cE_split_CD16 Mono_MI_results.pkl     0.677135
# Biolord_split_CD4 T_MI_results.pkl          0.609861
# dis2p_cE_split_NK_MI_results.pkl            0.711337
# Biolord_split_CD14 Mono_MI_results.pkl      0.666108
# Biolord_split_CD8 T_MI_results.pkl          0.685887
# Biolord_split_CD16 Mono_MI_results.pkl      0.665990
# dis2p_cE_split_CD8 T_MI_results.pkl         0.705154
# dis2p_cE_split_CD4 T_MI_results.pkl         0.735023
# dis2p_cE_split_T_MI_results.pkl             0.691922
# Biolord_split_DC_MI_results.pkl             0.621977
# Biolord_split_NK_MI_results.pkl             0.643924
# Biolord_split_T_MI_results.pkl              0.638725
# dis2p_cE_split_CD14 Mono_MI_results.pkl     0.725511
# scDisInfact_split_CD14 Mono_MI_results.pkl -0.198023
# dis2p_cE_split_B_MI_results.pkl             0.724274
# Biolord_split_B_MI_results.pkl              0.620112
# scDisInfact_split_CD16 Mono_MI_results.pkl -0.423035
# scDisInfact_split_CD8 T_MI_results.pkl     -0.420468
# scDisInfact_split_NK_MI_results.pkl        -0.431541
# scDisInfact_split_T_MI_results.pkl         -0.396200
# scDisInfact_split_DC_MI_results.pkl        -0.422618
# scDisInfact_split_CD4 T_MI_results.pkl     -0.397118
# dis2p_cE_split_DC_MI_results.pkl            0.752986
# scDisInfact_split_B_MI_results.pkl         -0.383955
# dis2p_cE_split_CD16 Mono_MI_results.pkl     0.696111
# Biolord_split_CD4 T_MI_results.pkl          0.609861
# dis2p_cE_split_NK_MI_results.pkl            0.734542
# Biolord_split_CD14 Mono_MI_results.pkl      0.666108
# Biolord_split_CD8 T_MI_results.pkl          0.699419
# Biolord_split_CD16 Mono_MI_results.pkl      0.665990
# dis2p_cE_split_CD8 T_MI_results.pkl         0.724621
# dis2p_cE_split_CD4 T_MI_results.pkl         0.662989
# dis2p_cE_split_T_MI_results.pkl             0.687882
# Biolord_split_DC_MI_results.pkl             0.621977
# Biolord_split_NK_MI_results.pkl             0.643924
# Biolord_split_T_MI_results.pkl              0.638725
# dis2p_cE_split_CD14 Mono_MI_results.pkl     0.692826
# scDisInfact_split_CD14 Mono_MI_results.pkl -0.221657
# dis2p_cE_split_B_MI_results.pkl             0.736369

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract the default colors from seaborn
default_palette = sns.color_palette()  # This gives you the default colors

# Create a custom palette with the desired order
custom_palette = {
    'dis2p': default_palette[0],     # Blue
    'Biolord': default_palette[1],   # Orange
    'scDisInfact': default_palette[2] # Green
}

fig, axes = plt.subplots(1, 2, figsize=(8, 8), sharey=True)

sns.barplot(df[df['Metric'] == 'maxMIG'],
            x='Model',
            y='Value',
            hue='Model', 
            errorbar='se',
            order=['dis2p', 'Biolord', 'scDisInfact'], 
            palette=custom_palette,
            ax=axes[0])

for p in axes[0].patches:
    height = p.get_height()
    axes[0].text(
        p.get_x() + p.get_width() / 2 - 0.2,  # x coordinate of the text
        height,  # y coordinate of the text
        f'{height:.2f}',  # text to be displayed
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )
axes[0].set_title('MaxMIG')


sns.barplot(df[df['Metric'] == 'concatMIG'], 
            x='Model', 
            y='Value', 
            hue='Model', 
            errorbar='se', 
            order=['dis2p', 'Biolord', 'scDisInfact'],  
            palette=custom_palette,
            ax=axes[1])

for p in axes[1].patches:
    height = p.get_height()
    axes[1].text(
        p.get_x() + p.get_width() / 2 - 0.2,  # x coordinate of the text
        height,  # y coordinate of the text
        f'{height:.2f}',  # text to be displayed
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )
axes[1].set_title('ConcatMIG')

axes[0].spines[['right', 'top']].set_visible(False)
axes[1].spines[['right', 'top']].set_visible(False)

plt.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0, hspace=None)

plt.show()
