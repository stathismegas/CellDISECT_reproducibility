# %%
# %cd /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/dis2p_reproducibility/reproduce_benchmarks/haber/MIG/results
# Out:
# /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/dis2p_reproducibility/reproduce_benchmarks/haber/MIG/results

# %%
import pickle
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
# !ls
# Out:
# Biolord_split_allOut_Endocrine_hpoly10_MI_results.pkl
# Biolord_split_allOut_Endocrine_salmonella_MI_results.pkl
# Biolord_split_allOut_Enterocyte_hpoly10_MI_results.pkl
# Biolord_split_allOut_Enterocyte.Progenitor_hpoly10_MI_results.pkl
# Biolord_split_allOut_Enterocyte.Progenitor_salmonella_MI_results.pkl
# Biolord_split_allOut_Enterocyte_salmonella_MI_results.pkl
# Biolord_split_allOut_Goblet_hpoly10_MI_results.pkl
# Biolord_split_allOut_Goblet_salmonella_MI_results.pkl
# Biolord_split_allOut_Stem_hpoly10_MI_results.pkl
# Biolord_split_allOut_Stem_salmonella_MI_results.pkl
# Biolord_split_allOut_TA.Early_hpoly10_MI_results.pkl
# Biolord_split_allOut_TA.Early_salmonella_MI_results.pkl
# Biolord_split_allOut_TA_hpoly10_MI_results.pkl
# Biolord_split_allOut_TA_salmonella_MI_results.pkl
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl
# Biolord_split_allOut_Tuft_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Endocrine_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Enterocyte_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Enterocyte.Progenitor_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Enterocyte_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Goblet_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Goblet_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Stem_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Stem_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_TA.Early_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_TA.Early_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_TA_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_TA_salmonella_MI_results.pkl
# dis2p_cE_split_allOut_Tuft_hpoly10_MI_results.pkl
# dis2p_cE_split_allOut_Tuft_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Endocrine_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Enterocyte_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Enterocyte.Progenitor_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Enterocyte.Progenitor_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Enterocyte_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Goblet_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Goblet_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Stem_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Stem_salmonella_MI_results.pkl
# scDisInfact_split_allOut_TA.Early_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_TA.Early_salmonella_MI_results.pkl
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_TA_salmonella_MI_results.pkl
# scDisInfact_split_allOut_Tuft_hpoly10_MI_results.pkl
# scDisInfact_split_allOut_Tuft_salmonella_MI_results.pkl

# %%
mig_max = {}
mig_cat = {}
for file in os.listdir():
    with open(file, 'rb') as fp:
        MI, MI_not_max, MI_not, MI_dif_max, MI_dif, maxMIG, concatMIG = pickle.load(fp)
        mig_max[file] = maxMIG
        mig_cat[file] = concatMIG

# %%
mig_max_df = pd.DataFrame(mig_max, index=['MaxMIG']).T
mig_max_df
# Out:
#                                                       MaxMIG
# Biolord_split_allOut_Endocrine_salmonella_MI_re...  0.147928
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpo...  0.386688
# Biolord_split_allOut_Enterocyte.Progenitor_hpol...  0.139379
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl -0.042873
# dis2p_cE_split_allOut_Tuft_salmonella_MI_result...  0.314756
# Biolord_split_allOut_TA.Early_salmonella_MI_res...  0.145080
# dis2p_cE_split_allOut_Enterocyte_salmonella_MI_...  0.331481
# dis2p_cE_split_allOut_Stem_salmonella_MI_result...  0.366153
# Biolord_split_allOut_Stem_salmonella_MI_results...  0.132399
# scDisInfact_split_allOut_Stem_hpoly10_MI_result... -0.044718
# Biolord_split_allOut_Enterocyte_salmonella_MI_r...  0.154034
# scDisInfact_split_allOut_Goblet_salmonella_MI_r... -0.035904
# Biolord_split_allOut_TA_salmonella_MI_results.pkl   0.130599
# Biolord_split_allOut_Goblet_salmonella_MI_resul...  0.141780
# scDisInfact_split_allOut_Enterocyte.Progenitor_... -0.043308
# dis2p_cE_split_allOut_Stem_hpoly10_MI_results.pkl   0.370308
# scDisInfact_split_allOut_Goblet_hpoly10_MI_resu... -0.031527
# dis2p_cE_split_allOut_Endocrine_salmonella_MI_r...  0.334698
# dis2p_cE_split_allOut_Tuft_hpoly10_MI_results.pkl   0.340371
# scDisInfact_split_allOut_TA.Early_hpoly10_MI_re... -0.036674
# scDisInfact_split_allOut_Stem_salmonella_MI_res... -0.036015
# dis2p_cE_split_allOut_Goblet_hpoly10_MI_results...  0.323320
# Biolord_split_allOut_Goblet_hpoly10_MI_results.pkl  0.128291
# dis2p_cE_split_allOut_Enterocyte.Progenitor_sal...  0.375815
# Biolord_split_allOut_TA_hpoly10_MI_results.pkl      0.150636
# dis2p_cE_split_allOut_TA_hpoly10_MI_results.pkl     0.328563
# Biolord_split_allOut_Enterocyte_hpoly10_MI_resu...  0.152810
# scDisInfact_split_allOut_TA.Early_salmonella_MI... -0.037387
# dis2p_cE_split_allOut_TA_salmonella_MI_results.pkl  0.373540
# dis2p_cE_split_allOut_TA.Early_hpoly10_MI_resul...  0.367657
# scDisInfact_split_allOut_Enterocyte_salmonella_... -0.011637
# dis2p_cE_split_allOut_Goblet_salmonella_MI_resu...  0.344121
# dis2p_cE_split_allOut_Enterocyte_hpoly10_MI_res...  0.374214
# scDisInfact_split_allOut_Enterocyte_hpoly10_MI_... -0.034537
# dis2p_cE_split_allOut_TA.Early_salmonella_MI_re...  0.359753
# Biolord_split_allOut_Endocrine_hpoly10_MI_resul...  0.154580
# Biolord_split_allOut_TA.Early_hpoly10_MI_result...  0.166694
# scDisInfact_split_allOut_Tuft_hpoly10_MI_result... -0.037019
# Biolord_split_allOut_Stem_hpoly10_MI_results.pkl    0.131889
# scDisInfact_split_allOut_Enterocyte.Progenitor_... -0.045499
# Biolord_split_allOut_Tuft_salmonella_MI_results...  0.143308
# scDisInfact_split_allOut_TA_salmonella_MI_resul... -0.039523
# Biolord_split_allOut_Enterocyte.Progenitor_salm...  0.128229
# scDisInfact_split_allOut_Tuft_salmonella_MI_res... -0.038908
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_r... -0.040672
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl    0.139115
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_resu...  0.375086
# scDisInfact_split_allOut_Endocrine_salmonella_M... -0.044369

# %%
mig_cat_df = pd.DataFrame(mig_cat, index=['ConcatMIG']).T
mig_cat_df
# Out:
#                                                     ConcatMIG
# Biolord_split_allOut_Endocrine_salmonella_MI_re...   0.156123
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpo...   0.478744
# Biolord_split_allOut_Enterocyte.Progenitor_hpol...   0.159641
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl  -0.106783
# dis2p_cE_split_allOut_Tuft_salmonella_MI_result...   0.444599
# Biolord_split_allOut_TA.Early_salmonella_MI_res...   0.162706
# dis2p_cE_split_allOut_Enterocyte_salmonella_MI_...   0.445833
# dis2p_cE_split_allOut_Stem_salmonella_MI_result...   0.467181
# Biolord_split_allOut_Stem_salmonella_MI_results...   0.154946
# scDisInfact_split_allOut_Stem_hpoly10_MI_result...  -0.110986
# Biolord_split_allOut_Enterocyte_salmonella_MI_r...   0.169946
# scDisInfact_split_allOut_Goblet_salmonella_MI_r...  -0.096190
# Biolord_split_allOut_TA_salmonella_MI_results.pkl    0.156058
# Biolord_split_allOut_Goblet_salmonella_MI_resul...   0.158141
# scDisInfact_split_allOut_Enterocyte.Progenitor_...  -0.120270
# dis2p_cE_split_allOut_Stem_hpoly10_MI_results.pkl    0.493375
# scDisInfact_split_allOut_Goblet_hpoly10_MI_resu...  -0.109490
# dis2p_cE_split_allOut_Endocrine_salmonella_MI_r...   0.442736
# dis2p_cE_split_allOut_Tuft_hpoly10_MI_results.pkl    0.455901
# scDisInfact_split_allOut_TA.Early_hpoly10_MI_re...  -0.115475
# scDisInfact_split_allOut_Stem_salmonella_MI_res...  -0.108950
# dis2p_cE_split_allOut_Goblet_hpoly10_MI_results...   0.429894
# Biolord_split_allOut_Goblet_hpoly10_MI_results.pkl   0.150067
# dis2p_cE_split_allOut_Enterocyte.Progenitor_sal...   0.462327
# Biolord_split_allOut_TA_hpoly10_MI_results.pkl       0.164169
# dis2p_cE_split_allOut_TA_hpoly10_MI_results.pkl      0.427884
# Biolord_split_allOut_Enterocyte_hpoly10_MI_resu...   0.180225
# scDisInfact_split_allOut_TA.Early_salmonella_MI...  -0.097043
# dis2p_cE_split_allOut_TA_salmonella_MI_results.pkl   0.466262
# dis2p_cE_split_allOut_TA.Early_hpoly10_MI_resul...   0.454751
# scDisInfact_split_allOut_Enterocyte_salmonella_...  -0.087110
# dis2p_cE_split_allOut_Goblet_salmonella_MI_resu...   0.435889
# dis2p_cE_split_allOut_Enterocyte_hpoly10_MI_res...   0.475995
# scDisInfact_split_allOut_Enterocyte_hpoly10_MI_...  -0.110171
# dis2p_cE_split_allOut_TA.Early_salmonella_MI_re...   0.453069
# Biolord_split_allOut_Endocrine_hpoly10_MI_resul...   0.184324
# Biolord_split_allOut_TA.Early_hpoly10_MI_result...   0.191478
# scDisInfact_split_allOut_Tuft_hpoly10_MI_result...  -0.107960
# Biolord_split_allOut_Stem_hpoly10_MI_results.pkl     0.149870
# scDisInfact_split_allOut_Enterocyte.Progenitor_...  -0.124556
# Biolord_split_allOut_Tuft_salmonella_MI_results...   0.158485
# scDisInfact_split_allOut_TA_salmonella_MI_resul...  -0.109131
# Biolord_split_allOut_Enterocyte.Progenitor_salm...   0.159691
# scDisInfact_split_allOut_Tuft_salmonella_MI_res...  -0.106603
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_r...  -0.110335
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl     0.152316
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_resu...   0.479195
# scDisInfact_split_allOut_Endocrine_salmonella_M...  -0.117470

# %%
df1 = mig_max_df.copy()
df1['Split'] = df1.index.str.split('_').str[-5] + '_' + df1.index.str.split('_').str[-4] + '_' + df1.index.str.split('_').str[-3]
df1['Model'] = df1.index.str.split('_').str[0]
df1['Metric'] = 'maxMIG'
df1['Value'] = df1['MaxMIG']
df1 = df1.drop(columns=['MaxMIG'])

df2 = mig_cat_df.copy()
df2['Split'] = df2.index.str.split('_').str[-5] + '_' + df2.index.str.split('_').str[-4] + '_' + df2.index.str.split('_').str[-3]
df2['Model'] = df2.index.str.split('_').str[0]
df2['Metric'] = 'concatMIG'
df2['Value'] = df2['ConcatMIG']
df2 = df2.drop(columns=['ConcatMIG'])

df = pd.concat([df1, df2])
df
# Out:
#                                                                                    Split  \
# Biolord_split_allOut_Endocrine_salmonella_MI_re...           allOut_Endocrine_salmonella
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpo...  allOut_Enterocyte.Progenitor_hpoly10
# Biolord_split_allOut_Enterocyte.Progenitor_hpol...  allOut_Enterocyte.Progenitor_hpoly10
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl                     allOut_TA_hpoly10
# dis2p_cE_split_allOut_Tuft_salmonella_MI_result...                allOut_Tuft_salmonella
# ...                                                                                  ...
# scDisInfact_split_allOut_Tuft_salmonella_MI_res...                allOut_Tuft_salmonella
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_r...              allOut_Endocrine_hpoly10
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl                     allOut_Tuft_hpoly10
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_resu...              allOut_Endocrine_hpoly10
# scDisInfact_split_allOut_Endocrine_salmonella_M...           allOut_Endocrine_salmonella
#
#                                                           Model     Metric  \
# Biolord_split_allOut_Endocrine_salmonella_MI_re...      Biolord     maxMIG
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpo...        dis2p     maxMIG
# Biolord_split_allOut_Enterocyte.Progenitor_hpol...      Biolord     maxMIG
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl  scDisInfact     maxMIG
# dis2p_cE_split_allOut_Tuft_salmonella_MI_result...        dis2p     maxMIG
# ...                                                         ...        ...
# scDisInfact_split_allOut_Tuft_salmonella_MI_res...  scDisInfact  concatMIG
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_r...  scDisInfact  concatMIG
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl        Biolord  concatMIG
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_resu...        dis2p  concatMIG
# scDisInfact_split_allOut_Endocrine_salmonella_M...  scDisInfact  concatMIG
#
#                                                        Value
# Biolord_split_allOut_Endocrine_salmonella_MI_re...  0.147928
# dis2p_cE_split_allOut_Enterocyte.Progenitor_hpo...  0.386688
# Biolord_split_allOut_Enterocyte.Progenitor_hpol...  0.139379
# scDisInfact_split_allOut_TA_hpoly10_MI_results.pkl -0.042873
# dis2p_cE_split_allOut_Tuft_salmonella_MI_result...  0.314756
# ...                                                      ...
# scDisInfact_split_allOut_Tuft_salmonella_MI_res... -0.106603
# scDisInfact_split_allOut_Endocrine_hpoly10_MI_r... -0.110335
# Biolord_split_allOut_Tuft_hpoly10_MI_results.pkl    0.152316
# dis2p_cE_split_allOut_Endocrine_hpoly10_MI_resu...  0.479195
# scDisInfact_split_allOut_Endocrine_salmonella_M... -0.117470
#
# [96 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract the default colors from seaborn
default_palette = sns.color_palette()  # This gives you the default colors

# Create a custom palette with the desired order
custom_palette = {
    'dis2p': default_palette[0],     # Blue
    'Biolord': default_palette[1],   # Orange
    'scDisInfact': default_palette[2] # Green
}

fig, axes = plt.subplots(1, 2, figsize=(8, 8), sharey=True)

sns.barplot(df[df['Metric'] == 'maxMIG'],
            x='Model',
            y='Value',
            hue='Model', 
            errorbar='se',
            order=['dis2p', 'Biolord', 'scDisInfact'], 
            palette=custom_palette,
            ax=axes[0])

for p in axes[0].patches:
    height = p.get_height()
    axes[0].text(
        p.get_x() + p.get_width() / 2 - 0.2,  # x coordinate of the text
        height,  # y coordinate of the text
        f'{height:.2f}',  # text to be displayed
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )
axes[0].set_title('MaxMIG')


sns.barplot(df[df['Metric'] == 'concatMIG'], 
            x='Model', 
            y='Value', 
            hue='Model', 
            errorbar='se', 
            order=['dis2p', 'Biolord', 'scDisInfact'],  
            palette=custom_palette,
            ax=axes[1])

for p in axes[1].patches:
    height = p.get_height()
    axes[1].text(
        p.get_x() + p.get_width() / 2 - 0.2,  # x coordinate of the text
        height,  # y coordinate of the text
        f'{height:.2f}',  # text to be displayed
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )
axes[1].set_title('ConcatMIG')

axes[0].spines[['right', 'top']].set_visible(False)
axes[1].spines[['right', 'top']].set_visible(False)

plt.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0, hspace=None)

plt.show()
