# %%
# enable autoreload
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import scanpy as sc
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Global seed set to 0

# %%
# %cd /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/notebooks
# Out:
# /lustre/scratch126/cellgen/team205/aa34/Arian/Dis2P/notebooks

# %%
adata = sc.read_h5ad('../eraslan_preprocessed1200_split_deg.h5ad')

# %%
adata_count = sc.read_h5ad('../eraslan_preprocessed1200_split.h5ad')

# %%
adata.layers['counts'].max()
# Out:
# 0.77312154

# %%
adata_count.layers['counts'].max()
# Out:
# 3370.0

# %%
adata.layers['counts'] = adata_count.layers['counts'].copy()

# %%
adata.X = adata.layers['counts'].copy()
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
adata.X.max()
# Out:
# WARNING: adata.X seems to be already log-transformed.
# 4.406719

# %%
adata.X.max()
adata.layers['counts'].max()
# Out:
# 3370.0

# %%
def check_difference(adata,  # OOD Adata
                cov_names,
                cov_values: str,
                cov_values_cf: str,):
    adata.X = adata.layers['counts']
    adata.obs['idx'] = [i for i in range(len(adata))]

    true_indices = pd.DataFrame([adata.obs[cov_name] == cov_values_cf[i] for i, cov_name in enumerate(cov_names)]).all(0).values
    true_idx = list(adata[true_indices].obs['idx'])
    
    source_indices = pd.DataFrame([adata.obs[cov_name] == cov_values[i] for i, cov_name in enumerate(cov_names)]).all(0).values
    source_idx = list(adata[source_indices].obs['idx'])
                    
    # true_idx = list(adata[adata.obs[cov_name] == cov_values_cf].obs['idx'])
    # source_idx = list(adata[adata.obs[cov_name] == cov_values].obs['idx'])

    true_adata = adata[adata.obs['idx'].isin(true_idx)].copy()
    source_adata = adata[adata.obs['idx'].isin(source_idx)].copy()

    # sc.pp.normalize_total(true_adata)
    true_x_count = torch.tensor(true_adata.X.toarray())
    # sc.pp.normalize_total(source_adata)
    cf_x_count = torch.tensor(source_adata.X.toarray())

    x_true = true_x_count
    x_ctrl = cf_x_count

    x_true = np.log1p(x_true)
    x_ctrl = np.log1p(x_ctrl)
    return x_ctrl, x_true

# %%
def check_difference_no_reference(adata,  # OOD Adata
                cov_names,
                cov_values_cf: str,):
    adata.X = adata.layers['counts']
    adata.obs['idx'] = [i for i in range(len(adata))]

    true_indices = pd.DataFrame([adata.obs[cov_name] == cov_values_cf[i] for i, cov_name in enumerate(cov_names)]).all(0).values
    true_idx = list(adata[true_indices].obs['idx'])
    
    source_indices = pd.DataFrame([adata.obs[cov_name] != cov_values_cf[i] for i, cov_name in enumerate(cov_names)]).all(0).values
    source_idx = list(adata[source_indices].obs['idx'])
                    
    # true_idx = list(adata[adata.obs[cov_name] == cov_values_cf].obs['idx'])
    # source_idx = list(adata[adata.obs[cov_name] == cov_values].obs['idx'])

    true_adata = adata[adata.obs['idx'].isin(true_idx)].copy()
    source_adata = adata[adata.obs['idx'].isin(source_idx)].copy()

    # sc.pp.normalize_total(true_adata)
    true_x_count = torch.tensor(true_adata.X.toarray())
    # sc.pp.normalize_total(source_adata)
    cf_x_count = torch.tensor(source_adata.X.toarray())

    x_true = true_x_count
    x_ctrl = cf_x_count

    x_true = np.log1p(x_true)
    x_ctrl = np.log1p(x_ctrl)
    return x_ctrl, x_true

# %%
bisex_ct = [ct for ct in adata.obs['Broad cell type'].unique() if len(adata[adata.obs['Broad cell type'] == ct].obs['sex'].unique()) == 2]

adata.X = adata.layers['counts'].copy()
sc.pp.log1p(adata)
adata.obs['cov_sex'] = adata.obs['Broad cell type'].astype(str) + '_' + adata.obs.sex.astype(str)
mt = [gene for gene in adata.var['gene_name'] if gene.startswith('MT-')]
rp = [gene for gene in adata.var['gene_name'] if (gene.startswith('RPL') or gene.startswith('RPS'))]
remove = mt + rp
adata_ = adata[:, ~adata.var['gene_name'].isin(remove)]

adata_ = adata_[adata_.obs['Broad cell type'].isin(bisex_ct)]

groupby='cov_sex'
control_group='female'
covariate='Broad cell type'
key_added="rank_genes_groups_sex"
n_genes=200
return_dict=False
rankby_abs=True
gene_dict = {}
cov_categories = adata_.obs[covariate].unique()
for cov_cat in cov_categories:
    print(cov_cat)
    # name of the control group in the groupby obs column
    # control_group_cov = "_".join([cov_cat, control_group])
    # if control_group_cov not in adata_.obs[groupby].values:
    #     continue
    # subset adata to cells belonging to a covariate category
    adata_cov = adata_[adata_.obs[covariate] == cov_cat]
    
    # compute DEGs
    sc.tl.rank_genes_groups(
        adata_cov,
        groupby=groupby,
        # reference=control_group_cov,
        rankby_abs=rankby_abs,
        n_genes=n_genes,
        use_raw=False,
        method='wilcoxon',
    )
    # scanpy.get.rank_genes_groups_df(adata, group, *, key=‘rank_genes_groups’, pval_cutoff=None, log2fc_min=None, log2fc_max=None, gene_symbols=None)

    # add entries to dictionary of gene sets
    # de_genes = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"])
    # de_pvals = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["pvals"])
    de_genes_groups = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"]).columns
    
    de_genes = {}
    lfc = {}
    for group in de_genes_groups:
        # de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=None, log2fc_min=None, log2fc_max=None)['names']
        de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['names']
        lfc[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['logfoldchanges']
        
        lfc_indices = lfc[group].abs().sort_values(ascending=False).index
        de_genes[group] = de_genes[group][lfc_indices].reset_index(drop=True)
        
        gene_dict[group] = de_genes[group].tolist()
        # gene_dict[group] = de_pvals[group].tolist()

adata_.uns[key_added] = gene_dict
adata.uns[key_added] = adata_.uns[key_added]
adata.X = adata.layers['counts'].copy()
# Out:
# WARNING: adata.X seems to be already log-transformed.
# Myocyte (sk. muscle, cytoplasmic)
# Myocyte (NMJ-rich)
# Endothelial cell (vascular)
# Myocyte (sk. muscle)
# Fibroblast
# Pericyte/SMC
# Immune (DC/macrophage)
# Adipocyte
# Schwann cell
# Satellite cell
# Endothelial cell (lymphatic)
# Immune (T cell)
# Immune (NK cell)
# Immune (mast cell)
# Epithelial cell (luminal)
# Epithelial cell (basal)
# Immune (B cell)
# Neuroendocrine
# Myocyte (smooth muscle)
# Neuronal
# ICCs
# Myocyte (cardiac, cytoplasmic)
# Myocyte (cardiac)
# Epithelial cell (alveolar type II)
# Immune (alveolar macrophage)
# Epithelial cell (ciliated)
# Epithelial cell (alveolar type I)
# Epithelial cell (club)
# Sweat gland cell
# Unknown
# Epithelial cell (basal keratinocyte)
# Sebaceous gland cell
# Epithelial cell (suprabasal keratinocyte)
# Melanocyte

# %%
adata.uns[key_added].keys()
# Out:
# dict_keys(['Myocyte (sk. muscle, cytoplasmic)_female', 'Myocyte (sk. muscle, cytoplasmic)_male', 'Myocyte (NMJ-rich)_female', 'Myocyte (NMJ-rich)_male', 'Endothelial cell (vascular)_female', 'Endothelial cell (vascular)_male', 'Myocyte (sk. muscle)_female', 'Myocyte (sk. muscle)_male', 'Fibroblast_female', 'Fibroblast_male', 'Pericyte/SMC_female', 'Pericyte/SMC_male', 'Immune (DC/macrophage)_female', 'Immune (DC/macrophage)_male', 'Adipocyte_female', 'Adipocyte_male', 'Schwann cell_female', 'Schwann cell_male', 'Satellite cell_female', 'Satellite cell_male', 'Endothelial cell (lymphatic)_female', 'Endothelial cell (lymphatic)_male', 'Immune (T cell)_female', 'Immune (T cell)_male', 'Immune (NK cell)_female', 'Immune (NK cell)_male', 'Immune (mast cell)_female', 'Immune (mast cell)_male', 'Epithelial cell (luminal)_female', 'Epithelial cell (luminal)_male', 'Epithelial cell (basal)_female', 'Epithelial cell (basal)_male', 'Immune (B cell)_female', 'Immune (B cell)_male', 'Neuroendocrine_female', 'Neuroendocrine_male', 'Myocyte (smooth muscle)_female', 'Myocyte (smooth muscle)_male', 'Neuronal_female', 'Neuronal_male', 'ICCs_female', 'ICCs_male', 'Myocyte (cardiac, cytoplasmic)_female', 'Myocyte (cardiac, cytoplasmic)_male', 'Myocyte (cardiac)_female', 'Myocyte (cardiac)_male', 'Epithelial cell (alveolar type II)_female', 'Epithelial cell (alveolar type II)_male', 'Immune (alveolar macrophage)_female', 'Immune (alveolar macrophage)_male', 'Epithelial cell (ciliated)_female', 'Epithelial cell (ciliated)_male', 'Epithelial cell (alveolar type I)_female', 'Epithelial cell (alveolar type I)_male', 'Epithelial cell (club)_female', 'Epithelial cell (club)_male', 'Sweat gland cell_female', 'Sweat gland cell_male', 'Unknown_female', 'Unknown_male', 'Epithelial cell (basal keratinocyte)_female', 'Epithelial cell (basal keratinocyte)_male', 'Sebaceous gland cell_female', 'Sebaceous gland cell_male', 'Epithelial cell (suprabasal keratinocyte)_female', 'Epithelial cell (suprabasal keratinocyte)_male', 'Melanocyte_female', 'Melanocyte_male'])

# %%
adata.uns[key_added]['Myocyte (sk. muscle, cytoplasmic)_female']
# Out:
# ['C8orf22',
#  'ANGPTL4',
#  'ACTC1',
#  'MYH1',
#  'LPL',
#  'RP11-532N4.2',
#  'AC016723.4',
#  'MYF6',
#  'MT1E',
#  'CSRP3',
#  'CKB',
#  'TNNI2',
#  'CHAC1',
#  'FTL',
#  'TNNC2',
#  'LMCD1',
#  'TNNT3',
#  'CD36',
#  'MYLPF',
#  'ERRFI1',
#  'MT2A',
#  'COX7C',
#  'MT1A',
#  'RNF19B',
#  'ANKRD2',
#  'MYH2',
#  'HSPB1',
#  'XIRP2',
#  'TMSB4X',
#  'CKM',
#  'IFITM3',
#  'MYL2',
#  'CKMT2',
#  'ACTG1',
#  'S100A6',
#  'TXNRD1',
#  'PGAM2',
#  'FTH1',
#  'TPM1',
#  'ZNF90',
#  'NEXN',
#  'APOO',
#  'CRYAB',
#  'EEF1A2',
#  'MRPL41',
#  'PDLIM3',
#  'KLHL41',
#  'TNNI1',
#  'G0S2',
#  'BAIAP2L1',
#  'ACTB',
#  'MYL3',
#  'SEPW1',
#  'TRDN',
#  'SLC25A4',
#  'GLUL',
#  'UQCR10',
#  'ACTA1',
#  'CTNNA3',
#  'COX6B1',
#  'NDUFB3',
#  'SLC26A3',
#  'AC072062.1',
#  'GAPDH',
#  'UQCRH',
#  'COX4I1',
#  'RASGEF1B',
#  'CYCS',
#  'TPT1',
#  'DES',
#  'XPO5',
#  'TNNT1',
#  'COX5B',
#  'RP11-451G4.2',
#  'SLN',
#  'CST3',
#  'CHCHD10',
#  'ALDOA',
#  'CMYA5',
#  'MYL12A',
#  'ATP5J',
#  'FLNC',
#  'TPM3',
#  'NEB',
#  'TTN']

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    cell_type_to_check = key.split('_')[0]
    cov_names = ['sex']
    cov_values = ['male' if key.split('_')[1] == 'female' else 'female']
    cov_values_cf = [key.split('_')[1]]
    if len(degs) < 2:
        continue
    x_ctrl, x_true = check_difference(
                adata[adata.obs['Broad cell type'] == cell_type_to_check],
                cov_names,
                cov_values,
                cov_values_cf,)
    degs = np.where(np.isin(adata.var_names, degs))[0]
    x_true_deg = x_true[:, degs]
    x_ctrl_deg = x_ctrl[:, degs]

    r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
    r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]
    
    difference_dict['Group'].append(key)
    difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
    difference_dict['n_DEGs'].append(len(degs))

# %%
difference_dict_sex = difference_dict.copy()

# %%
difference_df_sex = pd.DataFrame(difference_dict_sex)
difference_df_sex
# Out:
#                                         Group  Correlation with control  \
# 0    Myocyte (sk. muscle, cytoplasmic)_female                      0.82
# 1      Myocyte (sk. muscle, cytoplasmic)_male                      0.82
# 2                   Myocyte (NMJ-rich)_female                      0.61
# 3                     Myocyte (NMJ-rich)_male                      0.61
# 4          Endothelial cell (vascular)_female                      0.90
# 5            Endothelial cell (vascular)_male                      0.90
# 6                 Myocyte (sk. muscle)_female                      0.78
# 7                   Myocyte (sk. muscle)_male                      0.78
# 8                           Fibroblast_female                      0.87
# 9                             Fibroblast_male                      0.87
# 10                        Pericyte/SMC_female                      0.77
# 11                          Pericyte/SMC_male                      0.77
# 12              Immune (DC/macrophage)_female                      0.86
# 13                Immune (DC/macrophage)_male                      0.86
# 14                           Adipocyte_female                      0.60
# 15                             Adipocyte_male                      0.60
# 16                        Schwann cell_female                      0.87
# 17                          Schwann cell_male                      0.87
# 18        Endothelial cell (lymphatic)_female                      0.93
# 19          Endothelial cell (lymphatic)_male                      0.93
# 20                     Immune (T cell)_female                      0.72
# 21                       Immune (T cell)_male                      0.72
# 22                  Immune (mast cell)_female                      0.93
# 23                    Immune (mast cell)_male                      0.93
# 24           Epithelial cell (luminal)_female                      0.01
# 25             Epithelial cell (luminal)_male                      0.01
# 26             Epithelial cell (basal)_female                      0.07
# 27               Epithelial cell (basal)_male                      0.07
# 28                      Neuroendocrine_female                     -0.75
# 29                        Neuroendocrine_male                     -0.75
# 30             Myocyte (smooth muscle)_female                      0.90
# 31               Myocyte (smooth muscle)_male                      0.90
# 32                                ICCs_female                      0.95
# 33                                  ICCs_male                      0.95
# 34      Myocyte (cardiac, cytoplasmic)_female                      0.89
# 35        Myocyte (cardiac, cytoplasmic)_male                      0.89
# 36                   Myocyte (cardiac)_female                      0.88
# 37                     Myocyte (cardiac)_male                      0.88
# 38  Epithelial cell (alveolar type II)_female                      0.89
# 39    Epithelial cell (alveolar type II)_male                      0.89
# 40        Immune (alveolar macrophage)_female                      0.65
# 41          Immune (alveolar macrophage)_male                      0.65
# 42          Epithelial cell (ciliated)_female                      0.76
# 43            Epithelial cell (ciliated)_male                      0.76
# 44   Epithelial cell (alveolar type I)_female                      0.83
# 45     Epithelial cell (alveolar type I)_male                      0.83
# 46              Epithelial cell (club)_female                     -0.02
# 47                Epithelial cell (club)_male                     -0.02
# 48                    Sweat gland cell_female                      0.23
# 49                      Sweat gland cell_male                      0.23
# 50                             Unknown_female                      0.77
# 51                               Unknown_male                      0.77
# 52                          Melanocyte_female                      0.34
# 53                            Melanocyte_male                      0.34
#
#     n_DEGs
# 0       85
# 1       85
# 2       12
# 3       12
# 4      138
# 5      138
# 6      155
# 7      155
# 8      195
# 9      195
# 10      47
# 11      47
# 12     114
# 13     114
# 14      92
# 15      92
# 16      30
# 17      30
# 18      81
# 19      81
# 20      19
# 21      19
# 22       5
# 23       5
# 24     200
# 25     200
# 26     200
# 27     200
# 28       9
# 29       9
# 30     200
# 31     200
# 32       4
# 33       4
# 34     191
# 35     191
# 36     200
# 37     200
# 38     200
# 39     200
# 40     200
# 41     200
# 42      20
# 43      20
# 44     145
# 45     145
# 46     147
# 47     147
# 48      12
# 49      12
# 50      13
# 51      13
# 52      14
# 53      14

# %%
difference_sex_ct = difference_df_sex[::2].reset_index(drop=True)
difference_sex_ct.Group = difference_sex_ct.Group.apply(lambda x: x.split('_')[0])
difference_sex_ct
# Out:
#                                  Group  Correlation with control  n_DEGs
# 0    Myocyte (sk. muscle, cytoplasmic)                      0.82      85
# 1                   Myocyte (NMJ-rich)                      0.61      12
# 2          Endothelial cell (vascular)                      0.90     138
# 3                 Myocyte (sk. muscle)                      0.78     155
# 4                           Fibroblast                      0.87     195
# 5                         Pericyte/SMC                      0.77      47
# 6               Immune (DC/macrophage)                      0.86     114
# 7                            Adipocyte                      0.60      92
# 8                         Schwann cell                      0.87      30
# 9         Endothelial cell (lymphatic)                      0.93      81
# 10                     Immune (T cell)                      0.72      19
# 11                  Immune (mast cell)                      0.93       5
# 12           Epithelial cell (luminal)                      0.01     200
# 13             Epithelial cell (basal)                      0.07     200
# 14                      Neuroendocrine                     -0.75       9
# 15             Myocyte (smooth muscle)                      0.90     200
# 16                                ICCs                      0.95       4
# 17      Myocyte (cardiac, cytoplasmic)                      0.89     191
# 18                   Myocyte (cardiac)                      0.88     200
# 19  Epithelial cell (alveolar type II)                      0.89     200
# 20        Immune (alveolar macrophage)                      0.65     200
# 21          Epithelial cell (ciliated)                      0.76      20
# 22   Epithelial cell (alveolar type I)                      0.83     145
# 23              Epithelial cell (club)                     -0.02     147
# 24                    Sweat gland cell                      0.23      12
# 25                             Unknown                      0.77      13
# 26                          Melanocyte                      0.34      14

# %%
ax = sns.barplot(difference_sex_ct.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Sex | P-Val < 0.1 DEGs')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90, fontsize=12)
plt.show()

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    if ('Epithelial' in key) and (difference_df_sex[difference_df_sex['Group'] == key]['Correlation with control'] < 0.5).values:
        cell_type_to_check = key.split('_')[0]
        cov_names = ['sex']
        cov_values = ['male' if key.split('_')[1] == 'female' else 'female']
        cov_values_cf = [key.split('_')[1]]
        if len(degs) < 2:
            continue
        x_ctrl, x_true = check_difference(
                    adata[adata.obs['Broad cell type'] == cell_type_to_check],
                    cov_names,
                    cov_values,
                    cov_values_cf,)
        degs = np.where(np.isin(adata.var_names, degs[:50]))[0]
        x_true_deg = x_true[:, degs]
        x_ctrl_deg = x_ctrl[:, degs]

        r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
        r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]

        difference_dict['Group'].append(key)
        difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
        difference_dict['n_DEGs'].append(len(degs))
difference_pd = pd.DataFrame(difference_dict)

difference_sex_Epithelial = difference_pd[::2].reset_index(drop=True)
difference_sex_Epithelial.Group = difference_sex_Epithelial.Group.apply(lambda x: x.split('_')[0])
difference_sex_Epithelial
# Out:
#                        Group  Correlation with control  n_DEGs
# 0  Epithelial cell (luminal)                     -0.20      50
# 1    Epithelial cell (basal)                     -0.36      50
# 2     Epithelial cell (club)                     -0.02      50

# %%
ax = sns.barplot(difference_sex_Epithelial.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Sex | Epithelial Cell Type | P-Val < 0.1 DEGs --> Top 50 (More genes existed)\n')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90)
plt.show()

# %%
adata.X = adata.layers['counts'].copy()
sc.pp.log1p(adata)
adata.obs['cov_tissue'] = adata.obs['Broad cell type'].astype(str) + '_' + adata.obs.tissue.astype(str)
mt = [gene for gene in adata.var['gene_name'] if gene.startswith('MT-')]
rp = [gene for gene in adata.var['gene_name'] if (gene.startswith('RPL') or gene.startswith('RPS'))]
remove = mt + rp
adata_ = adata[:, ~adata.var['gene_name'].isin(remove)]

# adata_ = adata_[adata_.obs['Broad cell type'].isin(bisex_ct)]

groupby='cov_tissue'
covariate='Broad cell type'
key_added="rank_genes_groups_tissue"
n_genes=200
return_dict=False
rankby_abs=True
gene_dict = {}
cov_categories = adata_.obs[covariate].unique()
for cov_cat in cov_categories:
    print(cov_cat)
    # subset adata to cells belonging to a covariate category
    adata_cov = adata_[adata_.obs[covariate] == cov_cat]
    if len(adata_cov.obs['tissue'].unique()) < 2:
        continue
    # compute DEGs
    sc.tl.rank_genes_groups(
        adata_cov,
        groupby=groupby,
        # reference=control_group_cov,
        rankby_abs=rankby_abs,
        n_genes=n_genes,
        use_raw=False,
        method='wilcoxon',
    )
    # scanpy.get.rank_genes_groups_df(adata, group, *, key=‘rank_genes_groups’, pval_cutoff=None, log2fc_min=None, log2fc_max=None, gene_symbols=None)

    # add entries to dictionary of gene sets
    # de_genes = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"])
    # de_pvals = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["pvals"])
    de_genes_groups = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"]).columns
    
    de_genes = {}
    lfc = {}
    for group in de_genes_groups:
        # de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=None, log2fc_min=None, log2fc_max=None)['names']
        de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['names']
        lfc[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['logfoldchanges']
        
        lfc_indices = lfc[group].abs().sort_values(ascending=False).index
        de_genes[group] = de_genes[group][lfc_indices].reset_index(drop=True)
        
        gene_dict[group] = de_genes[group].tolist()

adata_.uns[key_added] = gene_dict
adata.uns[key_added] = adata_.uns[key_added]
adata.X = adata.layers['counts'].copy()
# Out:
# WARNING: adata.X seems to be already log-transformed.
# Myocyte (sk. muscle, cytoplasmic)
# Myocyte (NMJ-rich)
# Endothelial cell (vascular)
# Myocyte (sk. muscle)
# Fibroblast
# Pericyte/SMC
# Immune (DC/macrophage)
# Adipocyte
# Schwann cell
# Satellite cell
# Endothelial cell (lymphatic)
# Immune (T cell)
# Immune (NK cell)
# Immune (mast cell)
# Epithelial cell (luminal)
# Myoepithelial (basal)
# Epithelial cell (squamous)
# Epithelial cell (suprabasal)
# Myofibroblast
# Epithelial cell (basal)
# Mucous cell
# Immune (B cell)
# Immune (DC)
# Neuroendocrine
# Myocyte (smooth muscle)
# Neuronal
# ICCs
# Myocyte (cardiac, cytoplasmic)
# Myocyte (cardiac)
# Epithelial cell (alveolar type II)
# Immune (alveolar macrophage)
# Epithelial cell (ciliated)
# Epithelial cell (alveolar type I)
# Epithelial cell (club)
# Epithelial cell (Hillock)
# Sweat gland cell
# Epithelial cell (cornified keratinocyte)
# Unknown
# Epithelial cell (basal keratinocyte)
# Sebaceous gland cell
# Epithelial cell (mature keratinocyte)
# Epithelial cell (suprabasal keratinocyte)
# Melanocyte
# Immune (Langerhans)

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    cell_type_to_check = key.split('_')[0]
    cov_names = ['tissue']
    cov_values_cf = [key.split('_')[1]]
    if len(degs) < 2:
        continue
    x_ctrl, x_true = check_difference_no_reference(
                adata[adata.obs['Broad cell type'] == cell_type_to_check],
                cov_names,
                cov_values_cf,)
    degs = np.where(np.isin(adata.var_names, degs))[0]
    x_true_deg = x_true[:, degs]
    x_ctrl_deg = x_ctrl[:, degs]

    r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
    r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]
    
    difference_dict['Group'].append(key)
    difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
    difference_dict['n_DEGs'].append(len(degs))

# %%
difference_dict_tissue = difference_dict.copy()
difference_dict_tissue = pd.DataFrame(difference_dict_tissue)
difference_dict_tissue
# Out:
#                                                 Group  \
# 0   Endothelial cell (vascular)_anterior wall of l...
# 1                  Endothelial cell (vascular)_breast
# 2   Endothelial cell (vascular)_esophagus muscular...
# 3           Endothelial cell (vascular)_gastrocnemius
# 4    Endothelial cell (vascular)_lingula of left lung
# ..                                                ...
# 71                      Neuroendocrine_prostate gland
# 72  Myocyte (smooth muscle)_esophagus muscularis m...
# 73             Myocyte (smooth muscle)_prostate gland
# 74        Epithelial cell (club)_lingula of left lung
# 75              Epithelial cell (club)_prostate gland
#
#     Correlation with control  n_DEGs
# 0                       0.79     182
# 1                       0.70      77
# 2                       0.70     156
# 3                       0.80      92
# 4                       0.50     200
# ..                       ...     ...
# 71                     -0.75       9
# 72                      0.82     200
# 73                      0.82     200
# 74                     -0.05     200
# 75                     -0.05     200
#
# [76 rows x 3 columns]

# %%
ax = sns.barplot(difference_dict_tissue.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Tissue | P-Val < 0.1 DEGs')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90, fontsize=6)
plt.show()

# %%
difference_dict_tissue[difference_dict_tissue['Correlation with control'] < 0.1]
# Out:
#                                            Group  Correlation with control  \
# 20             Pericyte/SMC_lingula of left lung                     -0.20
# 39                    Schwann cell_gastrocnemius                     -0.52
# 52          Immune (T cell)_lingula of left lung                     -0.02
# 61       Immune (mast cell)_lingula of left lung                     -0.17
# 63              Epithelial cell (luminal)_breast                      0.01
# 64      Epithelial cell (luminal)_prostate gland                      0.01
# 65  Epithelial cell (basal)_lingula of left lung                     -0.31
# 66                Epithelial cell (basal)_mucosa                      0.07
# 67        Epithelial cell (basal)_prostate gland                      0.08
# 68          Immune (B cell)_lingula of left lung                     -0.19
# 70                         Neuroendocrine_mucosa                     -0.75
# 71                 Neuroendocrine_prostate gland                     -0.75
# 74   Epithelial cell (club)_lingula of left lung                     -0.05
# 75         Epithelial cell (club)_prostate gland                     -0.05
#
#     n_DEGs
# 20      21
# 39       6
# 52      11
# 61       8
# 63     200
# 64     200
# 65      60
# 66     200
# 67     200
# 68       4
# 70       9
# 71       9
# 74     200
# 75     200

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    if ('Epithelial' in key) and (difference_dict_tissue[difference_dict_tissue['Group'] == key]['Correlation with control'] < 0.5).values:
        cell_type_to_check = key.split('_')[0]
        cov_names = ['tissue']
        cov_values_cf = [key.split('_')[1]]
        if len(degs) < 2:
            continue
        x_ctrl, x_true = check_difference_no_reference(
                    adata[adata.obs['Broad cell type'] == cell_type_to_check],
                    cov_names,
                    cov_values_cf,)
        degs = np.where(np.isin(adata.var_names, degs[:50]))[0]
        x_true_deg = x_true[:, degs]
        x_ctrl_deg = x_ctrl[:, degs]

        r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
        r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]

        difference_dict['Group'].append(key)
        difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
        difference_dict['n_DEGs'].append(len(degs))
difference_pd = pd.DataFrame(difference_dict)

difference_tissue_Epithelial = difference_pd
difference_tissue_Epithelial
# Out:
#                                           Group  Correlation with control  \
# 0              Epithelial cell (luminal)_breast                     -0.20
# 1      Epithelial cell (luminal)_prostate gland                     -0.20
# 2  Epithelial cell (basal)_lingula of left lung                     -0.32
# 3                Epithelial cell (basal)_mucosa                     -0.36
# 4        Epithelial cell (basal)_prostate gland                     -0.37
# 5   Epithelial cell (club)_lingula of left lung                     -0.22
# 6         Epithelial cell (club)_prostate gland                     -0.22
#
#    n_DEGs
# 0      50
# 1      50
# 2      50
# 3      50
# 4      50
# 5      50
# 6      50

# %%
ax = sns.barplot(difference_tissue_Epithelial.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Tissue | Epithelial Cell Type | P-Val < 0.1 DEGs --> Top 50 (More genes existed)\n')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90)
plt.show()

# %%
adata.X = adata.layers['counts'].copy()
sc.pp.log1p(adata)
adata.obs['cov_age'] = adata.obs['Broad cell type'].astype(str) + '_' + adata.obs.Age_bin.astype(str)
mt = [gene for gene in adata.var['gene_name'] if gene.startswith('MT-')]
rp = [gene for gene in adata.var['gene_name'] if (gene.startswith('RPL') or gene.startswith('RPS'))]
remove = mt + rp
adata_ = adata[:, ~adata.var['gene_name'].isin(remove)]

# adata_ = adata_[adata_.obs['Broad cell type'].isin(bisex_ct)]

groupby='cov_age'
covariate='Broad cell type'
key_added="rank_genes_groups_age"
n_genes=200
return_dict=False
rankby_abs=True
gene_dict = {}
cov_categories = adata_.obs[covariate].unique()
for cov_cat in cov_categories:
    print(cov_cat)
    # subset adata to cells belonging to a covariate category
    adata_cov = adata_[adata_.obs[covariate] == cov_cat]
    if len(adata_cov.obs['Age_bin'].unique()) < 2:
        continue
    age_groups = adata_cov.obs['Age_bin'].unique()
    for age_group in age_groups:
        if len(adata_cov[adata_cov.obs['Age_bin'] == age_group]) < 2:
            adata_cov = adata_cov[adata_cov.obs['Age_bin'] != age_group]
    # compute DEGs
    sc.tl.rank_genes_groups(
        adata_cov,
        groupby=groupby,
        # reference=control_group_cov,
        rankby_abs=rankby_abs,
        n_genes=n_genes,
        use_raw=False,
        method='wilcoxon',
    )
    # scanpy.get.rank_genes_groups_df(adata, group, *, key=‘rank_genes_groups’, pval_cutoff=None, log2fc_min=None, log2fc_max=None, gene_symbols=None)

    # add entries to dictionary of gene sets
    # de_genes = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"])
    # de_pvals = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["pvals"])
    de_genes_groups = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"]).columns
    
    de_genes = {}
    lfc = {}
    for group in de_genes_groups:
        # de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=None, log2fc_min=None, log2fc_max=None)['names']
        de_genes[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['names']
        lfc[group] = sc.get.rank_genes_groups_df(adata_cov, group, key='rank_genes_groups', pval_cutoff=0.1, log2fc_min=None, log2fc_max=None)['logfoldchanges']
        
        lfc_indices = lfc[group].abs().sort_values(ascending=False).index
        de_genes[group] = de_genes[group][lfc_indices].reset_index(drop=True)
        
        gene_dict[group] = de_genes[group].tolist()

adata_.uns[key_added] = gene_dict
adata.uns[key_added] = adata_.uns[key_added]
adata.X = adata.layers['counts'].copy()
# Out:
# WARNING: adata.X seems to be already log-transformed.
# Myocyte (sk. muscle, cytoplasmic)
# Myocyte (NMJ-rich)
# Endothelial cell (vascular)
# Myocyte (sk. muscle)
# Fibroblast
# Pericyte/SMC
# Immune (DC/macrophage)
# Adipocyte
# Schwann cell
# Satellite cell
# Endothelial cell (lymphatic)
# Immune (T cell)
# Immune (NK cell)
# Immune (mast cell)
# Epithelial cell (luminal)
# Myoepithelial (basal)
# Epithelial cell (squamous)
# Epithelial cell (suprabasal)
# Myofibroblast
# Epithelial cell (basal)
# Mucous cell
# Immune (B cell)
# Immune (DC)
# Neuroendocrine
# Myocyte (smooth muscle)
# Neuronal
# ICCs
# Myocyte (cardiac, cytoplasmic)
# Myocyte (cardiac)
# Epithelial cell (alveolar type II)
# Immune (alveolar macrophage)
# Epithelial cell (ciliated)
# Epithelial cell (alveolar type I)
# Epithelial cell (club)
# Epithelial cell (Hillock)
# Sweat gland cell
# Epithelial cell (cornified keratinocyte)
# Unknown
# Epithelial cell (basal keratinocyte)
# Sebaceous gland cell
# Epithelial cell (mature keratinocyte)
# Epithelial cell (suprabasal keratinocyte)
# Melanocyte
# Immune (Langerhans)

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    cell_type_to_check = key.split('_')[0]
    cov_names = ['Age_bin']
    cov_values_cf = [key.split('_')[1]]
    if len(degs) < 2:
        continue
    x_ctrl, x_true = check_difference_no_reference(
                adata[adata.obs['Broad cell type'] == cell_type_to_check],
                cov_names,
                cov_values_cf,)
    degs = np.where(np.isin(adata.var_names, degs))[0]
    x_true_deg = x_true[:, degs]
    x_ctrl_deg = x_ctrl[:, degs]

    r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
    r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]
    
    difference_dict['Group'].append(key)
    difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
    difference_dict['n_DEGs'].append(len(degs))

# %%
difference_dict_age = difference_dict.copy()
difference_dict_age = pd.DataFrame(difference_dict_age)
difference_dict_age
# Out:
#                                        Group  Correlation with control  n_DEGs
# 0    Myocyte (sk. muscle, cytoplasmic)_41-50                      0.82      85
# 1    Myocyte (sk. muscle, cytoplasmic)_51-60                      0.88      91
# 2    Myocyte (sk. muscle, cytoplasmic)_61-70                      0.62      82
# 3                   Myocyte (NMJ-rich)_41-50                      0.61      12
# 4                   Myocyte (NMJ-rich)_51-60                      0.64      12
# ..                                       ...                       ...     ...
# 99                    Sweat gland cell_51-60                      0.37      21
# 100                            Unknown_21-40                      0.76      11
# 101                            Unknown_51-60                      0.76      11
# 102                         Melanocyte_21-40                      0.34      14
# 103                         Melanocyte_51-60                      0.34      14
#
# [104 rows x 3 columns]

# %%
ax = sns.barplot(difference_dict_age.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Age | P-Val < 0.1 DEGs')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90, fontsize=6)
plt.show()

# %%
difference_dict_age[difference_dict_age['Correlation with control'] < 0.5]
# Out:
#                                Group  Correlation with control  n_DEGs
# 12                  Fibroblast_21-40                      0.42     198
# 24                   Adipocyte_21-40                      0.38      45
# 26                   Adipocyte_51-60                      0.38      94
# 45          Immune (mast cell)_21-40                      0.23      16
# 49   Epithelial cell (luminal)_21-40                      0.13     200
# 53       Myoepithelial (basal)_21-40                      0.05      49
# 54       Myoepithelial (basal)_41-50                      0.05      49
# 64     Epithelial cell (basal)_21-40                      0.34     200
# 67     Epithelial cell (basal)_61-70                      0.27     200
# 71              Neuroendocrine_21-40                     -0.96       5
# 92      Epithelial cell (club)_41-50                      0.48     151
# 93      Epithelial cell (club)_51-60                      0.36     182
# 94      Epithelial cell (club)_61-70                      0.45     188
# 96   Epithelial cell (Hillock)_51-60                      0.49     122
# 97   Epithelial cell (Hillock)_61-70                      0.49      79
# 98            Sweat gland cell_21-40                      0.37      21
# 99            Sweat gland cell_51-60                      0.37      21
# 102                 Melanocyte_21-40                      0.34      14
# 103                 Melanocyte_51-60                      0.34      14

# %%
from scipy.stats import pearsonr

difference_dict = {'Group': [], 'Correlation with control': [], 'n_DEGs': []}
for key, degs in adata.uns[key_added].items():
    if ('Epithelial' in key) and (difference_dict_age[difference_dict_age['Group'] == key]['Correlation with control'] < 0.5).values:
        cell_type_to_check = key.split('_')[0]
        cov_names = ['Age_bin']
        cov_values_cf = [key.split('_')[1]]
        if len(degs) < 2:
            continue
        x_ctrl, x_true = check_difference_no_reference(
                    adata[adata.obs['Broad cell type'] == cell_type_to_check],
                    cov_names,
                    cov_values_cf,)
        degs = np.where(np.isin(adata.var_names, degs[:50]))[0]
        x_true_deg = x_true[:, degs]
        x_ctrl_deg = x_ctrl[:, degs]

        r2_mean_base_deg = pearsonr(x_true_deg.mean(0), x_ctrl_deg.mean(0))[0]
        r2_var_base_deg = pearsonr(x_true_deg.var(0), x_ctrl_deg.var(0))[0]

        difference_dict['Group'].append(key)
        difference_dict['Correlation with control'].append(round(r2_mean_base_deg, 2))
        difference_dict['n_DEGs'].append(len(degs))
difference_pd = pd.DataFrame(difference_dict)

difference_age_Epithelial = difference_pd
difference_age_Epithelial
# Out:
#                              Group  Correlation with control  n_DEGs
# 0  Epithelial cell (luminal)_21-40                      0.55      50
# 1    Epithelial cell (basal)_21-40                     -0.05      50
# 2    Epithelial cell (basal)_61-70                      0.44      50
# 3     Epithelial cell (club)_41-50                      0.16      50
# 4     Epithelial cell (club)_51-60                      0.64      50
# 5     Epithelial cell (club)_61-70                      0.16      50
# 6  Epithelial cell (Hillock)_51-60                      0.11      50
# 7  Epithelial cell (Hillock)_61-70                      0.16      50

# %%
ax = sns.barplot(difference_age_Epithelial.sort_values(by='Correlation with control'),
                 x='Group', 
                 y='Correlation with control',
                 hue='n_DEGs',
                 legend='brief',
                 )
ax.set_title('Age bin | Epithelial Cell Type | P-Val < 0.1 DEGs --> Top 50 (More genes existed)\n')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=90)
plt.show()

# %%
adata.uns.keys()
# Out:
# dict_keys(['Broad cell type (numbers)_colors', 'Broad cell type_colors', 'Broad cell type_sizes', 'Tissue composition_colors', '_scvi_manager_uuid', '_scvi_uuid', 'citation', "dendrogram_['Broad cell type']", 'hvg', 'leiden', 'log1p', 'neighbors', 'paga', 'prep_colors', 'rank_genes_groups_age', 'rank_genes_groups_ood', 'rank_genes_groups_ood_ct', 'rank_genes_groups_sex', 'rank_genes_groups_tissue', 'schema_reference', 'schema_version', 'title', 'umap'])

# %%
adata.X = adata.layers['counts'].copy()
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
adata.X.max()
# Out:
# 4.406719

# %%
adata.layers['counts'].max()
# Out:
# 3370.0

# %%
adata.write('../eraslan_preprocessed1200_split_deg.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 209125 × 1200
#     obs: 'Sample ID_prep', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'n_genes', 'fpr', 'prep', 'individual', 'nGenes', 'nUMIs', 'PercentMito', 'PercentRibo', 'Age_bin', 'Sample ID', 'donor_id', 'Sample ID short', 'RIN score from PAXgene tissue Aliquot', 'RIN score from Frozen tissue Aliquot', 'Autolysis Score', 'Sample Ischemic Time (mins)', 'scrublet', 'scrublet_score', 'batch', 'n_counts', 'tissue-individual-prep', 'Broad cell type', 'Granular cell type', 'introns', 'junctions', 'exons', 'sense', 'antisense', 'intergenic', 'exon_ratio', 'intron_ratio', 'junction_ratio', 'log10_nUMIs', 'leiden', 'leiden_tissue', 'Tissue composition', 'Cell types level 2', 'Cell types level 3', 'Broad cell type numbers', 'Broad cell type (numbers)', 'channel', 'development_stage_ontology_term_id', 'suspension_type', 'concat-identifier', 'hca_data_portal_donor_uuid', 'hca_data_portal_cellsuspension_uuid', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'tissue_idx', 'Sample ID_idx', 'cell_type_idx', 'sex_idx', 'Age_bin_idx', 'split', '_scvi_batch', '_scvi_labels', 'cov_sex', 'split_ct', 'cov_tissue', 'cov_age', 'CoarseCellType', 'split_Epithelial_basal', 'split_Epithelial_luminal'
#     var: 'Chromosome', 'Source', 'Start', 'End', 'Strand', 'gene_name', 'gene_source', 'gene_biotype', 'gene_length', 'gene_coding_length', 'Approved symbol', 'Approved name', 'Status', 'Previous symbols', 'Alias symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'name'
#     uns: 'Broad cell type (numbers)_colors', 'Broad cell type_colors', 'Broad cell type_sizes', 'Tissue composition_colors', '_scvi_manager_uuid', '_scvi_uuid', 'citation', "dendrogram_['Broad cell type']", 'hvg', 'leiden', 'log1p', 'neighbors', 'paga', 'prep_colors', 'rank_genes_groups_age', 'rank_genes_groups_ood', 'rank_genes_groups_ood_ct', 'rank_genes_groups_sex', 'rank_genes_groups_tissue', 'schema_reference', 'schema_version', 'title', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_vae_mean', 'X_vae_samples', 'X_vae_var', '_scvi_extra_categorical_covs'
#     layers: 'counts'

# %%
# !wget https://datasets.cellxgene.cziscience.com/502da516-aa72-415a-b1de-133ffb7b344b.h5ad
# Out:
# --2024-05-11 10:01:39--  https://datasets.cellxgene.cziscience.com/502da516-aa72-415a-b1de-133ffb7b344b.h5ad
# Resolving datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)... 18.165.227.65, 18.165.227.61, 18.165.227.26, ...
# Connecting to datasets.cellxgene.cziscience.com (datasets.cellxgene.cziscience.com)|18.165.227.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1390976789 (1.3G) [binary/octet-stream]
# Saving to: ‘502da516-aa72-415a-b1de-133ffb7b344b.h5ad’
#
# 502da516-aa72-415a- 100%[===================>]   1.29G   286MB/s    in 4.5s
#
# 2024-05-11 10:01:44 (292 MB/s) - ‘502da516-aa72-415a-b1de-133ffb7b344b.h5ad’ saved [1390976789/1390976789]

# %%
cellxgene_adata = sc.read_h5ad('502da516-aa72-415a-b1de-133ffb7b344b.h5ad')

# %%
cellxgene_adata
# Out:
# AnnData object with n_obs × n_vars = 209126 × 32839
#     obs: 'Sample ID_prep', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'n_genes', 'fpr', 'prep', 'individual', 'nGenes', 'nUMIs', 'PercentMito', 'PercentRibo', 'Age_bin', 'Sample ID', 'donor_id', 'Sample ID short', 'RIN score from PAXgene tissue Aliquot', 'RIN score from Frozen tissue Aliquot', 'Autolysis Score', 'Sample Ischemic Time (mins)', 'scrublet', 'scrublet_score', 'batch', 'n_counts', 'tissue-individual-prep', 'Broad cell type', 'Granular cell type', 'introns', 'junctions', 'exons', 'sense', 'antisense', 'intergenic', 'exon_ratio', 'intron_ratio', 'junction_ratio', 'log10_nUMIs', 'leiden', 'leiden_tissue', 'Tissue composition', 'Cell types level 2', 'Cell types level 3', 'Broad cell type numbers', 'Broad cell type (numbers)', 'channel', 'development_stage_ontology_term_id', 'suspension_type', 'concat-identifier', 'hca_data_portal_donor_uuid', 'hca_data_portal_cellsuspension_uuid', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'Chromosome', 'Source', 'Start', 'End', 'Strand', 'gene_name', 'gene_source', 'gene_biotype', 'gene_length', 'gene_coding_length', 'Approved symbol', 'Approved name', 'Status', 'Previous symbols', 'Alias symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'Broad cell type (numbers)_colors', 'Broad cell type_colors', 'Broad cell type_sizes', 'Tissue composition_colors', 'citation', "dendrogram_['Broad cell type']", 'leiden', 'neighbors', 'paga', 'prep_colors', 'schema_reference', 'schema_version', 'title', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_vae_mean', 'X_vae_samples', 'X_vae_var'
